# %% [markdown]
# # Fake News Detection Project ->

# %% [markdown]
# Data Set Link -> https://www.kaggle.com/datasets/bhavikjikadara/fake-news-detection
# (Kaggle.com)

# %%
import numpy as np
import pandas as pd

# %%
true=pd.read_csv('true.csv')

# %%
fake=pd.read_csv('fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1       #True DataSet
fake['label']=0       #Fake DataSet

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %% [markdown]
# # Concatinate/merge both the table row wise

# %%
news = pd.concat([fake, true],axis=0)  # Now the true and the fake statements will come todether for easier recognition of fake and true news

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %% [markdown]
# # Feature Selection

# %%
news=news.drop(['title','subject','date'],axis=1)  # Deleting the 'title', 'subject' and date column because we don't need this

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news=news.sample(frac=1)                       #Reshuffling the data

# %%
news.head()
# Out:
#                                                     text  label
# 4749   We are all getting whiplash from Donald Trump ...      0
# 7406   LOS ANGELES (Reuters) - California voters turn...      1
# 3225   When former Tea Party congressman Joe Walsh de...      0
# 9898   WASHINGTON (Reuters) - Chinese Finance Ministe...      1
# 10453  (Reuters) - Virginia Governor Terry McAuliffe ...      1

# %%
news.reset_index(inplace=True)
news.head()
# Out:
#    index                                               text  label
# 0   4749  We are all getting whiplash from Donald Trump ...      0
# 1   7406  LOS ANGELES (Reuters) - California voters turn...      1
# 2   3225  When former Tea Party congressman Joe Walsh de...      0
# 3   9898  WASHINGTON (Reuters) - Chinese Finance Ministe...      1
# 4  10453  (Reuters) - Virginia Governor Terry McAuliffe ...      1

# %%
news.drop(['index'],axis=1, inplace=True)  #Removing the index col

# %%
news.head()
# Out:
#                                                 text  label
# 0  We are all getting whiplash from Donald Trump ...      0
# 1  LOS ANGELES (Reuters) - California voters turn...      1
# 2  When former Tea Party congressman Joe Walsh de...      0
# 3  WASHINGTON (Reuters) - Chinese Finance Ministe...      1
# 4  (Reuters) - Virginia Governor Terry McAuliffe ...      1

# %% [markdown]
# # Data Cleaning
# Making data more readable and clear to the machine

# %%
import re                         #Regular Expression Module

# %%
def wordopt(text):
    #Convert into lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+','',text)

    # Remove HTML tags
    text=re.sub(r'<.*?>', '',text)

    #Remove punctuation
    text=re.sub(r'[^\w\s]', '', text)

    #Remove digits
    text=re.sub(r'\d', '',text)

    #Remove newline characters
    text=re.sub(r'\n', ' ', text)

    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']    #all the words are in running letters with no numbers , digits and other unusefull things
# Out:
# 0        we are all getting whiplash from donald trump ...
# 1        los angeles reuters  california voters turned ...
# 2        when former tea party congressman joe walsh de...
# 3        washington reuters  chinese finance minister l...
# 4        reuters  virginia governor terry mcauliffe has...
#                                ...
# 44893    hong kong reuters  macau s mostly prodemocracy...
# 44894    honolulu reuters  a federal judge in hawaii in...
# 44895    pope francis is now the antichrist in the eyes...
# 44896    washington reuters  us treasury secretary stev...
# 44897    washington reuters  the pentagon on tuesday pr...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']        #Dependent variable
y = news['label']       #Independent vaiable

# %%
x
# Out:
# 0        we are all getting whiplash from donald trump ...
# 1        los angeles reuters  california voters turned ...
# 2        when former tea party congressman joe walsh de...
# 3        washington reuters  chinese finance minister l...
# 4        reuters  virginia governor terry mcauliffe has...
#                                ...
# 44893    hong kong reuters  macau s mostly prodemocracy...
# 44894    honolulu reuters  a federal judge in hawaii in...
# 44895    pope francis is now the antichrist in the eyes...
# 44896    washington reuters  us treasury secretary stev...
# 44897    washington reuters  the pentagon on tuesday pr...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 44893    1
# 44894    1
# 44895    0
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %% [markdown]
# # Diving data into test data and training data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)            # diving data into training and test as 70:30 ratio  (30 is for test data)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %% [markdown]
# # Feature Extraction
# Converting the text data into vector or numerical data to , so that it will be used by the machine more accurately

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x174749 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6461979 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x174749 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2718547 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # EDA
# Exploratory Data Analysis (EDA) can provide valuable insights into your dataset before building a machine learning model.

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from nltk) (1.3.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.5.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 349.4 kB/s eta 0:00:00 0:00:01
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 904.8 kB/s eta 0:00:00 0:00:01
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.8 MB/s eta 0:00:0000:0100:01
# Downloading regex-2024.5.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (774 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.1/774.1 kB 14.3 MB/s eta 0:00:0000:01
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 2.2 MB/s eta 0:00:00eta 0:00:01
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 1.9 MB/s eta 0:00:00eta 0:00:01
# Installing collected packages: tqdm, regex, click, nltk
# Successfully installed click-8.1.7 nltk-3.8.1 regex-2024.5.10 tqdm-4.66.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import matplotlib.pyplot as plt

# Distribution of label
plt.figure(figsize=(8, 6))
news['label'].value_counts().plot(kind='bar', color=['skyblue', 'orange'])
plt.title('Distribution of Labels')
plt.xlabel('Label')
plt.ylabel('Count')
plt.xticks([0, 1], ['Fake', 'True'], rotation=0)
plt.show()

# %%
# Text length distribution
news['text_length'] = news['text'].apply(lambda x: len(x.split()))
plt.figure(figsize=(8, 6))
plt.hist(news['text_length'], bins=30, color='skyblue')
plt.title('Text Length Distribution')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # MACHINE LEARNING

# %% [markdown]
# # Algorithm Used - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression # Importing LogisticRegression using sklearn linear_model

# %%
LR = LogisticRegression()

# %% [markdown]
# # Training the model with data

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9885671863400148

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7002
#            1       0.99      0.99      0.99      6468
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %% [markdown]
# # Using Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9958426132145508

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7002
#            1       1.00      1.00      1.00      6468
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %% [markdown]
# # Using RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9891610987379361

# %%
print(classification_report(y_test, predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7002
#            1       0.99      0.99      0.99      6468
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)
# Out:
# 0.9960653303637713

# %%
print(classification_report(y_test,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7002
#            1       0.99      1.00      1.00      6468
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %% [markdown]
#  # Predictive Model

# %%
def output_label(n):
    if n==0:
        return"It is a Fake News"
    elif n==1:
        return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text": [news]} # Corrected syntax for defining dictionary
    new_def_test = pd.DataFrame (testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test) # Assuming 'vectorization' is your vectorizer object
    pred_lr = LR.predict(new_xv_test)
    #pred_dtc = dtc.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)
    return "\n\nLogisticRegression Prediction: {} \nGradientBoostingClassifier Prediction: {} \nRandomForestClassifier Prediction: {}".format(
        output_label(pred_lr[0]), output_label(pred_gbc[0]), output_label(pred_rfc[0]))

# %%
news_article = str(input())
# Out:
#  US attacks China's Quantum research, spy balloons by adding 37 companies to ban list — Entity List aggressively targets potential military applications

# %%
manual_testing(news_article)
# Out:
# '\n\nLogisticRegression Prediction: It is a Fake News \nGradientBoostingClassifier Prediction: It is a Fake News \nRandomForestClassifier Prediction: It is a Fake News'

# %%
pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.34.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=16.8 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (2.2.1)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (10.3.0)
# Collecting protobuf<5,>=3.20 (from streamlit)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-16.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (8.2.3)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (4.10.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (3.1.43)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/codespace/.local/lib/python3.10/site-packages (from streamlit) (6.4)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl.metadata (37 kB)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /home/codespace/.local/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.21.1)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (2.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Downloading streamlit-1.34.0-py2.py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 20.0 MB/s eta 0:00:0000:0100:01
# Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 16.8 MB/s eta 0:00:0000:01
# Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 6.7 MB/s eta 0:00:00ta 0:00:01
# Downloading pyarrow-16.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 25.2 MB/s eta 0:00:0000:0100:01
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 24.4 MB/s eta 0:00:0000:0100:01m
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 5.0 MB/s eta 0:00:00:00:01
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 2.0 MB/s eta 0:00:000:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 2.1 MB/s eta 0:00:00eta 0:00:01
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 1.1 MB/s eta 0:00:00eta 0:00:01
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: watchdog, toolz, toml, pyarrow, protobuf, mdurl, cachetools, blinker, pydeck, markdown-it-py, rich, altair, streamlit
# Successfully installed altair-5.3.0 blinker-1.8.2 cachetools-5.3.3 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-4.25.3 pyarrow-16.0.0 pydeck-0.9.1 rich-13.7.1 streamlit-1.34.0 toml-0.10.2 toolz-0.12.1 watchdog-4.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# %%
st.title('Fake News Detector')
input_text = st.text_input('Enter news Article')

# %%
streamlit run /home/codespace/.local/lib/python3.10/site-packages/ipykernel_launcher.py
# Out:
#   Cell In[82], line 1
#     streamlit run /home/codespace/.local/lib/python3.10/site-packages/ipykernel_launcher.py
#               ^
# SyntaxError: invalid syntax
